# %%
import pickle
import gzip
import numpy
import collections

# %%
# data = pickle.load(open('1m.pkl/1m.pkl', 'rb'), encoding='latin1')

# %%
data = pickle.load(gzip.open('1m.pkl.gz', 'rb'), encoding='latin1')

# %%
data[0]
# Out:
# {'artist_name': 'Baka Beyond',
#  'duration': 368.14322,
#  'key': 9,
#  'loudness': -11.482,
#  'tempo': 139.092,
#  'track_name': 'Journey (Album Version)',
#  'year': 1995}

# %%
len(data)
# Out:
# 1000000

# %%
len(set(t['artist_name'] for t in data))
# Out:
# 72665

# %%
artist_counts = collections.Counter(t['artist_name'] for t in data)
artist_counts.most_common(5)
# Out:
# [('Michael Jackson', 194),
#  ('Johnny Cash', 193),
#  ('Beastie Boys', 187),
#  ('Joan Baez', 181),
#  ('Neil Diamond', 176)]

# %%
artist_counts['The Beatles']
# Out:
# 58

# %%
artist_counts['Queen']
# Out:
# 95

# %%
artist_counts['The Rolling Stones']
# Out:
# 171

# %%
[t for t in data if t['artist_name'] == 'The Beatles']
# Out:
# [{'artist_name': 'The Beatles',
#   'duration': 267.10159,
#   'key': 2,
#   'loudness': -57.871,
#   'tempo': 181.989,
#   'track_name': 'Larry Kane Interviews Derek Taylor',
#   'year': 0},
#  {'artist_name': 'The Beatles',
#   'duration': 263.88853,
#   'key': 1,
#   'loudness': -24.558,
#   'tempo': 75.276,
#   'track_name': 'Post Beatles Interview With George Harrison (c. 1976)',
#   'year': 0},
#  {'artist_name': 'The Beatles',
#   'duration': 179.51302,
#   'key': 5,
#   'loudness': -22.808,
#   'tempo': 111.16,
#   'track_name': 'John and George To Allan Lappin in Melbourne',
#   'year': 0},
#  {'artist_name': 'The Beatles',
#   'duration': 33.17506,
#   'key': 11,
#   'loudness': -21.798,
#   'tempo': 215.977,
#   'track_name': 'John Lennon on Yoko',
#   'year': 0},
#  {'artist_name': 'The Beatles',
#   'duration': 117.62893,
#   'key': 2,
#   'loudness': -21.31,
#   'tempo': 126.445,
# ...

# %%
[t for t in data if t['artist_name'] == 'Queen']
# Out:
# [{'artist_name': 'Queen',
#   'duration': 262.19057,
#   'key': 2,
#   'loudness': -13.386,
#   'tempo': 77.464,
#   'track_name': 'Love Of My Life',
#   'year': 1975},
#  {'artist_name': 'Queen',
#   'duration': 68.64934,
#   'key': 2,
#   'loudness': -18.707,
#   'tempo': 67.584,
#   'track_name': 'Dear Friends (1993 Digital Remaster)',
#   'year': 1974},
#  {'artist_name': 'Queen',
#   'duration': 247.71873,
#   'key': 10,
#   'loudness': -13.475,
#   'tempo': 180.291,
#   'track_name': 'Breakthru',
#   'year': 1989},
#  {'artist_name': 'Queen',
#   'duration': 123.16689,
#   'key': 11,
#   'loudness': -9.329,
#   'tempo': 81.346,
#   'track_name': 'We Will Rock You',
#   'year': 1973},
#  {'artist_name': 'Queen',
#   'duration': 378.06975,
#   'key': 9,
#   'loudness': -6.268,
#   'tempo': 155.912,
#   'track_name': "Now I'm Here",
#   'year': 1974},
#  {'artist_name': 'Queen',
#   'duration': 521.82159,
#   'key': 4,
#   'loudness': -10.479,
#   'tempo': 149.901,
# ...
